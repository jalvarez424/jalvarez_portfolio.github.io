# %% [markdown]
# # Student Performance Factors

# %% [markdown]
# Data Exploration

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:/Users/jalva/Projects/Data Analyst/Portfolio/Data Projects/Student Performance Factors/StudentPerformanceFactors.csv")
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
# Note: looks like we have some null values for Teacher Quality, Parental Education Level, and Distance from Home

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df.nunique()
# Out:
# Hours_Studied                 41
# Attendance                    41
# Parental_Involvement           3
# Access_to_Resources            3
# Extracurricular_Activities     2
# Sleep_Hours                    7
# Previous_Scores               51
# Motivation_Level               3
# Internet_Access                2
# Tutoring_Sessions              9
# Family_Income                  3
# Teacher_Quality                3
# School_Type                    2
# Peer_Influence                 3
# Physical_Activity              7
# Learning_Disabilities          2
# Parental_Education_Level       3
# Distance_from_Home             3
# Gender                         2
# Exam_Score                    45
# dtype: int64

# %%
# top 10 exam scorers
df.sort_values(by = "Exam_Score", ascending = False).head(10)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 1525             27          98                  Low              Medium
# 94               18          89                 High              Medium
# 2425             23          83                 High                High
# 3579             14          90                 High                High
# 6393             16          83                  Low              Medium
# 6347             28          96                 High                 Low
# 4192             28          90                  Low              Medium
# 919              21          74                 High              Medium
# 529              15          83               Medium              Medium
# 5966             25          99               Medium              Medium
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 1525                        Yes            6               93
# ...

# %%
# let's look at the correlation of numeric values - extent at which two variables are linearly related (meaning they change together at constant rate)
df.corr(numeric_only=True)
# Out:
#                    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# Hours_Studied           1.000000   -0.009908     0.010977         0.024846
# Attendance             -0.009908    1.000000    -0.015918        -0.020186
# Sleep_Hours             0.010977   -0.015918     1.000000        -0.021750
# Previous_Scores         0.024846   -0.020186    -0.021750         1.000000
# Tutoring_Sessions      -0.014282    0.014324    -0.012216        -0.013122
# Physical_Activity       0.004624   -0.022435    -0.000378        -0.011274
# Exam_Score              0.445455    0.581072    -0.017022         0.175079
#
#                    Tutoring_Sessions  Physical_Activity  Exam_Score
# Hours_Studied              -0.014282           0.004624    0.445455
# Attendance                  0.014324          -0.022435    0.581072
# Sleep_Hours                -0.012216          -0.000378   -0.017022
# Previous_Scores            -0.013122          -0.011274    0.175079
# ...

# %%
# looking at different plt styles to use
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# use dark_background plt style
plt.style.use("dark_background")

# %%
# let's use a heatmap to visualize this better
sns.heatmap(df.corr(numeric_only = True), annot = True)

plt.rcParams["figure.figsize"] = (7, 5)  # params are (width_size, height_size)
plt.rcParams["font.size"] = 10

plt.show()

# %%
# Note: Looking at this heatmap, we can see that the Hours Studied and Attendance has a decent correlation with the Exam Score.
#   So we can infer that it is possible that students who study more and attend more classes have higher exam scores.

# %%
# let's look at the averages based on Teacher Quality - remember to use numeric only or else it errors out
df.groupby("Teacher_Quality").mean(numeric_only = True).sort_values(by = "Exam_Score", ascending=False)
# Out:
#                  Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# Teacher_Quality
# High                 19.932717   80.047252     7.044171        75.329224
# Low                  19.989346   80.251142     7.013699        76.147641
# Medium               19.998217   79.936306     7.024968        74.738599
#
#                  Tutoring_Sessions  Physical_Activity  Exam_Score
# Teacher_Quality
# High                      1.496148           2.954802   67.676939
# Low                       1.490107           3.028919   66.753425
# Medium                    1.493248           2.965860   67.109299

# %%
# So looking at the values here, we can infer that the Teacher Quality didn't really have an impact on students, speaking in averages

# %%
# Let's look at the average of Exam Score based on Hours Studied
df2 = df.groupby("Hours_Studied")["Exam_Score"].mean()
df2
# Out:
# Hours_Studied
# 1     71.000000
# 2     63.000000
# 3     61.333333
# 4     61.647059
# 5     62.857143
# 6     63.470588
# 7     64.352941
# 8     64.155172
# 9     64.162791
# 10    64.393617
# 11    64.979452
# 12    64.765625
# 13    64.724771
# 14    65.576208
# 15    65.590476
# 16    66.182336
# 17    66.328084
# 18    67.042394
# 19    66.959184
# 20    66.950538
# 21    67.682135
# 22    67.480100
# 23    68.180049
# 24    68.187675
# 25    68.847751
# 26    68.665399
# 27    69.462882
# 28    69.608187
# 29    70.283582
# 30    70.617886
# 31    70.688312
# 32    70.944444
# 33    70.025000
# 34    70.724138
# 35    71.800000
# 36    71.181818
# 37    73.333333
# 38    72.714286
# 39    74.714286
# 43    78.000000
# 44    71.000000
# Name: Exam_Score, dtype: float64

# %%
# if we wanted to switch axises, use df.transpose() function
df2.plot()
# Out:
# <Axes: xlabel='Hours_Studied'>

# %%
# The above line graph shows linear progression between hours studied and exam scores. There are a few outliers where the exam score is not following progression around 0-3 hours studied
# and around 43-50 hours studied. There may be other factors which caused these students to do better or worse than others in their range.

# %%
# Let's use boxplot to look more into those outliers
df.boxplot(column="Hours_Studied")
# Out:
# <Axes: >

# %%
# might be better to find outliers with scatter plot
df.plot.scatter(x = "Hours_Studied", y = "Exam_Score")
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='Exam_Score'>

# %%
# Let's filter those values in the table to see if there might be a reason for the outliers
df.query("Hours_Studied <= 10 & Exam_Score >= 80").sort_values("Exam_Score", ascending=False)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 4779              1          88               Medium                High
# 2595              7          69               Medium                High
# 3141              7          63                 High                High
# 1351              9          61                 High              Medium
# 1863             10          76               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 4779                        Yes            4               72
# 2595                        Yes            8               54
# 3141                        Yes           10               90
# 1351                        Yes            6               77
# 1863                         No            6               76
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 4779             High             Yes                  3        Medium
# ...

# %%
# Looking at this query, though the student with the highest score has only 1 hour of study time, 
# he was probably able to get the highest score because he had 3 tutoring sessions over the 0-1 sessions the other students had.
# There might be other factors but I believe that is the most prominent.
